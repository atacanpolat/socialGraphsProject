# %% [markdown]
# # Character fetching

# %% [markdown]
# This notebook is about fetching information about the characters from the Naruto fandom page.

# %% [markdown]
# We start of by important the neccesary packages:

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import networkx as nx
import asyncio
import aiohttp
import json
from aiohttp import hdrs
from aiohttp import ClientResponseError, TooManyRedirects
from yarl import URL  # Import the URL class

# %% [markdown]
# The names of all characters are fetched from the URLs in the code below:

# %%
# Base URL for Narutopedia character category
url_base = 'https://naruto.fandom.com/wiki/Category:Characters{}'
query_list = [
    '', 
    '?from=Eiki+Fūma%0AEiki+Fūma', 
    '?from=Hidari%0AHidari', 
    '?from=Karai%0AKarai', 
    '?from=Matsuba%0AMatsuba', 
    '?from=Rikumaru%0ARikumaru', 
    '?from=Taiki%0ATaiki', 
    '?from=Yubina%0AYubina'
]

all_content = ""

for query in query_list:
    url = url_base.format(query)    
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        category_members = soup.find('div', {'class': 'category-page__members'})

        if category_members:
            content = category_members.get_text()
            all_content += content
        else:
            print("Div with class 'category-page__members' not found on the page.")
    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

# Save the concatenated content to a single text file
with open('narutopedia_combined_content.txt', 'w', encoding='utf-8') as file:
    file.write(all_content)
    print("Saved combined content to narutopedia_combined_content.txt")
# Out:
# Saved combined content to narutopedia_combined_content.txt

# %% [markdown]
# The content from above is stored into a txt file. In order to use the data further, we clean it a little:

# %%
cleaned_string = re.sub(r'.\t', '', all_content.replace('\n', ' ')).replace('\t', ' ')

# Split the input string by two or more whitespace characters using regular expression
name_list = re.split(r'\s{2,}', cleaned_string)

# Filter out any empty strings
name_list = [name.strip() for name in name_list if name.strip()]

names_list = []
for name in name_list:
    name=name.replace(' ', '_')
    names_list.append(name)

# %% [markdown]
# Now, we define a function that allows us to fetch the text from each character page. We fetch the text, and we fetch every time there is a hyperlink on the page (for instance to another character):

# %%
url_characters = 'https://naruto.fandom.com/wiki/{}'

characters_texts = {}
characters_links = {}

async def fetch_character_data(name, session):
    """
    Asynchronously fetch character data from a given URL.

    Parameters:
    - name (str): The name of the character.
    - session (aiohttp.ClientSession): An aiohttp client session.

    """
    url_character = url_characters.format(name)
    
    async with session.get(url_character) as response:
        if response.status == 200:
            html_content = await response.text()
            soup = BeautifulSoup(html_content, 'html.parser')
            
            category_members = soup.find_all('p')
            all_links = [tag['href'].replace('/wiki/', '') for tag in soup.select('p a[href]')]

            characters_links[name] = all_links

            # Use a list to store text content for each character
            characters_texts[name] = [data.get_text().strip() for data in category_members if data.get_text()]

async def main():
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_character_data(name, session) for name in names_list]
        await asyncio.gather(*tasks)

await main()

# %% [markdown]
# On each character page there is an infobox that contains a lot of different information about the attributes of the different characters. Those are fetched here:

# %%
url_base = 'https://naruto.fandom.com/wiki/{}'
characters_infobox = {}

async def fetch_infobox_data(name, session):
    """
    Asynchronously fetch infobox data for a character from a given URL.

    Parameters:
    - name (str): The name of the character.
    - session (aiohttp.ClientSession): An aiohttp client session.

    """
    url = url_base.format(name)

    async with session.get(url) as response:
        if response.status == 200:
            html_content = await response.text()
            soup = BeautifulSoup(html_content, 'html.parser')

            infobox_table = soup.find('table', class_='infobox')
            if infobox_table:
                keys = []
                values = []
                capture_info = False

                for row in infobox_table.find_all('tr'):
                    th = row.find('th')
                    td = row.find('td')

                    if th and 'Personal' in th.get_text():
                        capture_info = True
                        continue

                    if capture_info:
                        key = th.get_text(strip=True) if th else None
                        value = td.get_text(strip=True) if td else None

                        if td:
                            ul_values = []
                            for ul in td.find_all('ul', recursive=False):
                                li_values = [li.get_text(strip=True) for li in ul.find_all('li')]
                                ul_values.extend(li_values)

                            if ul_values:
                                key = key if key else "Additional Information"
                                keys.append(key)
                                values.append(ul_values)
                                continue

                        if th and 'mainheader' in th.get('class', []):
                            next_tr = row.find_next('tr')
                            if next_tr:
                                value = next_tr.get_text(strip=True)

                        if key and value:
                            keys.append(key)
                            values.append(value)

                result_dict = dict(zip(keys, values))
                characters_infobox[name] = result_dict
            else:
                print(f"No infobox found for {name}")
        else:
            print(f"Failed to fetch data for {name}. Status code: {response.status}")

async def main_2():
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_infobox_data(name, session) for name in names_list]
        await asyncio.gather(*tasks)

await main_2()
# Out:
# No infobox found for Zetsu

# %% [markdown]
# Now, all the data that has been fetched so far is stored into json files for future analysis:

# %%
# Save dictionary to a JSON file
with open('../data/characters_list.json', 'w') as json_file:
    json.dump(names_list, json_file)

with open('../data/characters_texts.json', 'w') as json_file:
    json.dump(characters_texts, json_file)

with open('../data/characters_links.json', 'w') as json_file:
    json.dump(characters_links, json_file)

with open('../data/characters_infobox.json', 'w') as json_file:
    json.dump(characters_infobox, json_file)

# %% [markdown]
# Now, we focus on the hyperlinks of the pages. If there is a hyperlink on a character page to another character, it is important that we fetch the header name of the linked character page, since the hyperlink not necessarily is the correct name of the linked character.

# %% [markdown]
# -------------------------------

# %%
url_characters = 'https://naruto.fandom.com/wiki/'

async def fetch_link_name(key, values, session, counter, progress_callback):
    """
    Asynchronously fetch header names for character links from a given URL.

    Parameters:
    - key (str): The key representing the character.
    - values (list): The list of character links.
    - session (aiohttp.ClientSession): An aiohttp client session.
    - counter (int): The counter to keep track of the total fetched header names.
    - progress_callback (function): A callback function to print progress.

    Returns:
    - int: The count of fetched header names.

    """
    header_names = []  # Store header names for each key
    for idx, value in enumerate(values, start=counter + 1):
        url_character = url_characters + value
        try:
            async with session.get(url_character) as response:
                if response.status == 200:
                    html_content = await response.text()
                    soup = BeautifulSoup(html_content, 'html.parser')

                    # Extract the header name
                    header_name = soup.find('h1', {'class': 'page-header__title'})
                    name = header_name.text.strip() if header_name else f"No header found for {value}"
                    header_names.append(name)

                    # Check and notify the progress callback every 100 fetches
                    if idx % 100 == 0:
                        progress_callback(key, idx)

        except aiohttp.ClientResponseError as e:
            print(f"ClientResponseError exception for {url_character}: {e}")
            continue
        except Exception as e:
            print(f"Exception for {url_character}: {e}")
            continue

    # Update the original dictionary with the fetched header names
    characters_links[key] = header_names
    return len(header_names)


async def process_batch(keys, session, counter, progress_callback):
    tasks = [fetch_link_name(key, values, session, counter, progress_callback) for key, values in characters_links.items() if key in keys]
    return await asyncio.gather(*tasks)

def print_progress(key, count):
    print(f"Fetched {count} header names for {key}")

async def main_3():
    async with aiohttp.ClientSession() as session:
        # Divide the keys into batches (adjust the batch size as needed)
        batch_size = 100
        keys_batches = [list(characters_links.keys())[i:i + batch_size] for i in range(0, len(characters_links), batch_size)]

        total_counter = 0
        for keys_batch in keys_batches:
            batch_results = await process_batch(keys_batch, session, total_counter, print_progress)
            total_counter += sum(batch_results)
            print(f"Total fetched header names: {total_counter}")

await main_3()
# Out:
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 100 header names for Ao
# Fetched 100 header names for Akatsuchi
# Fetched 100 header names for Asuma_Sarutobi
# Fetched 100 header names for Akamaru
# Fetched 100 header names for A_(Third_Raikage)
# Fetched 100 header names for Anko_Mitarashi
# Fetched 100 header names for A_(Fourth_Raikage)
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 200 header names for Asuma_Sarutobi
# Fetched 200 header names for A_(Fourth_Raikage)
# Total fetched header names: 2888
# Fetched 2900 header names for Bug
# Fetched 2900 header names for Chen
# Fetched 2900 header names for Danjō
# Fetched 2900 header names for Earth_Daimyō
# Fetched 2900 header names for Dekai
# Fetched 2900 header names for Chihare_Amano
# Fetched 2900 header names for Burami
# Fetched 2900 header names for Cursed_Warrior
# Fetched 2900 header names for Ebizō
# Fetched 2900 header names for Dōshin
# Fetched 2900 header names for Chūshin
# Fetched 2900 header names for Daemon
# Fetched 2900 header names for Dotō_Kazahana
# Fetched 2900 header names for Daore_Dōtonbori
# Fetched 2900 header names for Chōza_Akimichi
# Fetched 2900 header names for Condor
# Fetched 2900 header names for Datsuji
# Fetched 2900 header names for C
# Fetched 2900 header names for Dan_Katō
# Fetched 2900 header names for Dokku
# Fetched 2900 header names for Boro
# Fetched 2900 header names for Boruto_Uzumaki
# Fetched 2900 header names for Boar-Masked_Anbu_Member
# Fetched 2900 header names for Blue_B
# Fetched 2900 header names for Deepa
# Fetched 2900 header names for Demonic_Statue_of_the_Outer_Path
# Fetched 2900 header names for Code
# Fetched 2900 header names for Chōchō_Akimichi
# Fetched 2900 header names for Black_Zetsu
# Fetched 2900 header names for Deidara
# Fetched 2900 header names for Chūkaku
# Fetched 2900 header names for Delta
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 2900 header names for Disonasu
# Fetched 2900 header names for Buntan_Kurosuki
# Fetched 2900 header names for Chamaru
# Fetched 2900 header names for Byakuren
# Fetched 2900 header names for Chiriku
# Fetched 2900 header names for Danzō_Shimura
# Fetched 2900 header names for Chamū
# Fetched 2900 header names for Daichi
# Fetched 2900 header names for Chōji's_Mother
# Fetched 2900 header names for Daen_Nara
# Fetched 2900 header names for Chiyo
# Fetched 2900 header names for Bull
# Fetched 2900 header names for Dodai
# Fetched 2900 header names for Ebisu
# Fetched 2900 header names for Dōshu_Goetsu
# Fetched 2900 header names for Daimaru
# Fetched 2900 header names for Chōjūrō
# Fetched 2900 header names for Daikoku_Funeno
# Fetched 2900 header names for Darui
# Fetched 2900 header names for Eagle-Masked_Anbu_Member
# Fetched 2900 header names for Chōji_Akimichi
# Fetched 2900 header names for Denki_Kaminarimon
# Fetched 2900 header names for Denka
# Fetched 2900 header names for Bunpuku
# Fetched 2900 header names for Chūkichi
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 2900 header names for Butsuma_Senju
# Fetched 2900 header names for Doseki_Ganryū
# Fetched 2900 header names for Eiki_Fūma
# Fetched 3000 header names for Denki_Kaminarimon
# Fetched 3000 header names for Chōchō_Akimichi
# Fetched 3000 header names for Chiyo
# Fetched 3000 header names for Chōji_Akimichi
# Fetched 3000 header names for Darui
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 3000 header names for Chōjūrō
# Fetched 3000 header names for Danzō_Shimura
# Fetched 3000 header names for Boruto_Uzumaki
# Fetched 3000 header names for Demonic_Statue_of_the_Outer_Path
# Fetched 3000 header names for Black_Zetsu
# Fetched 3000 header names for Deidara
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 3100 header names for Chōji_Akimichi
# Fetched 3100 header names for Boruto_Uzumaki
# Fetched 3100 header names for Danzō_Shimura
# Fetched 3100 header names for Deidara
# Fetched 3100 header names for Black_Zetsu
# Fetched 3200 header names for Boruto_Uzumaki
# Fetched 3300 header names for Boruto_Uzumaki
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Total fetched header names: 7511
# Fetched 7600 header names for Gamakichi
# Fetched 7600 header names for Gamabunta
# Fetched 7600 header names for Fū
# Fetched 7600 header names for Gaara
# Fetched 7600 header names for Gengetsu_Hōzuki
# Fetched 7700 header names for Gaara
# Fetched 7800 header names for Gaara
# Fetched 7900 header names for Gaara
# Total fetched header names: 10168
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 10200 header names for Guruko
# Fetched 10200 header names for Hako_Kuroi
# Fetched 10200 header names for Han
# Fetched 10200 header names for Gitai
# Fetched 10200 header names for Hanzō
# Fetched 10200 header names for Giant_Snake-Tailed_Chameleon
# Fetched 10200 header names for Genma_Shiranui
# Fetched 10200 header names for Hana_Inuzuka
# Fetched 10200 header names for Guren
# Fetched 10200 header names for Hayate_Gekkō
# Fetched 10200 header names for Hamura_Ōtsutsuki
# Fetched 10200 header names for Hana_Kaka
# Fetched 10200 header names for Haku
# Fetched 10200 header names for Gyūki
# Fetched 10200 header names for Hanabi_Hyūga
# Fetched 10200 header names for Ginkaku
# Fetched 10200 header names for Hagoromo_Ōtsutsuki
# Fetched 10200 header names for Hiashi_Hyūga
# Fetched 10200 header names for Hashirama_Senju
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 10300 header names for Hiashi_Hyūga
# Fetched 10300 header names for Gyūki
# Fetched 10300 header names for Hagoromo_Ōtsutsuki
# Fetched 10300 header names for Hashirama_Senju
# Total fetched header names: 12932
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 13000 header names for Homura_Mitokado
# Fetched 13000 header names for Isobu
# Fetched 13000 header names for Inoichi_Yamanaka
# Fetched 13000 header names for Inojin_Yamanaka
# Fetched 13000 header names for Isshiki_Ōtsutsuki
# Fetched 13000 header names for Iruka_Umino
# Fetched 13000 header names for Hiruzen_Sarutobi
# Fetched 13000 header names for Ibiki_Morino
# Fetched 13000 header names for Iwabee_Yuino
# Fetched 13000 header names for Itachi_Uchiha
# Fetched 13000 header names for Himawari_Uzumaki
# Fetched 13000 header names for Indra_Ōtsutsuki
# Fetched 13000 header names for Hinata_Hyūga
# Fetched 13000 header names for Ino_Yamanaka
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 13100 header names for Hinata_Hyūga
# Fetched 13100 header names for Ino_Yamanaka
# Fetched 13100 header names for Hiruzen_Sarutobi
# Fetched 13100 header names for Itachi_Uchiha
# Fetched 13200 header names for Hinata_Hyūga
# Fetched 13200 header names for Ino_Yamanaka
# Fetched 13200 header names for Itachi_Uchiha
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 13300 header names for Ino_Yamanaka
# Fetched 13300 header names for Hinata_Hyūga
# Total fetched header names: 16831
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 16900 header names for Jirōbō
# Fetched 16900 header names for Kakashi_Hatake
# Fetched 16900 header names for Izumo_Kamizuki
# Fetched 16900 header names for Kankurō
# Fetched 16900 header names for Jūgo
# Fetched 16900 header names for Jiraiya
# Fetched 16900 header names for Kakuzu
# Fetched 16900 header names for Kabuto_Yakushi
# Fetched 16900 header names for Kaguya_Ōtsutsuki
# Fetched 17000 header names for Kankurō
# Fetched 17000 header names for Kakashi_Hatake
# Fetched 17000 header names for Jiraiya
# Fetched 17000 header names for Kabuto_Yakushi
# TooManyRedirects exception for https://naruto.fandom.com/wiki/http://en.wikipedia.orgBow_%26_Arrow: 0, message='', url=URL('https://naruto.fandom.com/wiki/http://en.wikipedia.orgBow_&_Arrow')
# Fetched 17100 header names for Jiraiya
# Fetched 17100 header names for Kakashi_Hatake
# Fetched 17100 header names for Kabuto_Yakushi
# Fetched 17200 header names for Kakashi_Hatake
# Fetched 17200 header names for Kabuto_Yakushi
# Fetched 17300 header names for Kakashi_Hatake
# Fetched 17400 header names for Kakashi_Hatake
# Fetched 17500 header names for Kakashi_Hatake
# Total fetched header names: 20681
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 20700 header names for Kido_Tsumiki
# Fetched 20700 header names for Kongō
# Fetched 20700 header names for Kisame_Hoshigaki
# Fetched 20700 header names for Kiiro
# Fetched 20700 header names for Kikunojō
# Fetched 20700 header names for Katasuke_Tōno
# Fetched 20700 header names for Kigiri
# Fetched 20700 header names for Koji_Kashin
# Fetched 20700 header names for Killer_B
# Fetched 20700 header names for Kasumi_(Castle_Dusk)
# Fetched 20700 header names for Kazami
# Fetched 20700 header names for Kazuma
# Fetched 20700 header names for Kihō
# Fetched 20700 header names for Kirara
# Fetched 20700 header names for Komugi
# Fetched 20700 header names for Kokuyō
# Fetched 20700 header names for Kin_Tsuchi
# Fetched 20700 header names for Katsuyu
# Fetched 20700 header names for Kirisame
# Fetched 20700 header names for Jinin_Akebino
# Fetched 20700 header names for Kegon
# Fetched 20700 header names for Konan
# Fetched 20700 header names for Kinshiki_Ōtsutsuki
# Fetched 20700 header names for Kokuō
# Fetched 20700 header names for Kimimaro
# Fetched 20700 header names for Karyū
# Fetched 20700 header names for Kawaki
# Fetched 20700 header names for Karin
# Fetched 20700 header names for Kiri_(ninja)
# Fetched 20700 header names for King_of_Hell
# Fetched 20700 header names for Kidōmaru
# Fetched 20700 header names for Karui
# Fetched 20700 header names for Kitsuchi
# Fetched 20700 header names for Kiba_Inuzuka
# Fetched 20700 header names for Kinkaku
# Fetched 20800 header names for Kidōmaru
# Fetched 20800 header names for Kawaki
# Fetched 20800 header names for Kisame_Hoshigaki
# Fetched 20800 header names for Killer_B
# Fetched 20800 header names for Konan
# Fetched 20800 header names for Karin
# Fetched 20800 header names for Kiba_Inuzuka
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 20900 header names for Killer_B
# Fetched 20900 header names for Kiba_Inuzuka
# Fetched 21000 header names for Kiba_Inuzuka
# Total fetched header names: 24097
# Fetched 24100 header names for Kina_Kodon
# Fetched 24100 header names for Komitsu
# Fetched 24100 header names for Kosuke_Maruboshi
# Fetched 24100 header names for Koshō
# Fetched 24100 header names for Kosuke
# Fetched 24100 header names for Kunugi_Mokume
# Fetched 24100 header names for Korobi
# Fetched 24100 header names for Kōji_(Suna)
# Fetched 24100 header names for Koyuki_Kazahana
# Fetched 24100 header names for Kotetsu_Hagane
# Fetched 24100 header names for Kussaku
# Fetched 24100 header names for Lightning_Daimyō
# Fetched 24100 header names for Maroi
# Fetched 24100 header names for Kū
# Fetched 24100 header names for Kujaku
# Fetched 24100 header names for Magire_Kakuremino
# Fetched 24100 header names for Kōtarō_Fūma
# Fetched 24100 header names for Marui
# Fetched 24100 header names for Manabu_Akado
# Fetched 24100 header names for Kuwa_Yokohori
# Fetched 24100 header names for Kō_(Anbu)
# Fetched 24100 header names for Madara_Uchiha
# Fetched 24100 header names for Maruta
# Fetched 24100 header names for Lyla
# Fetched 24100 header names for Makinami_Senka
# Fetched 24100 header names for Manari
# Fetched 24100 header names for Kōmei
# Fetched 24100 header names for Kusune
# Fetched 24100 header names for Matsu
# Fetched 24100 header names for Kuroma_Tatsushiro
# Fetched 24100 header names for Lando
# Fetched 24100 header names for Mahiru
# Fetched 24100 header names for Korega
# Fetched 24100 header names for Leo
# Fetched 24100 header names for Makibi
# Fetched 24100 header names for Kōza_Kubisaki
# Fetched 24100 header names for Kurobachi
# Fetched 24100 header names for Kunijirō
# Fetched 24100 header names for Kōsuke_(Scientist)
# Fetched 24100 header names for Kusushi
# Fetched 24100 header names for Kōta
# Fetched 24100 header names for Mangetsu_Hōzuki
# Fetched 24100 header names for Kūi_Dōtonbori
# Fetched 24100 header names for Matatabi
# Fetched 24100 header names for Mabo
# Fetched 24100 header names for Kusabi
# Fetched 24100 header names for Master_Puppet
# Fetched 24100 header names for Kurenai_Yūhi
# Fetched 24100 header names for Margo
# Fetched 24100 header names for Konoha_Astronomer
# Fetched 24100 header names for Kotohime
# Fetched 24100 header names for Manda_II
# Fetched 24100 header names for Kusuna
# Fetched 24100 header names for Kozuchi
# Fetched 24100 header names for Kuromaru
# Fetched 24100 header names for Kōrogi
# Fetched 24100 header names for Lily_Himeno
# Fetched 24100 header names for Magire
# Fetched 24100 header names for Kuma_Panda
# Fetched 24100 header names for Masako
# Fetched 24100 header names for Mashō
# Fetched 24100 header names for Kō_Kogare
# Fetched 24100 header names for Kusuma
# Fetched 24100 header names for Kumo_Reincarnated_Shinobi
# Fetched 24100 header names for Kyōya
# Fetched 24100 header names for Kushimaru_Kuriarare
# Fetched 24100 header names for Kumadori
# Fetched 24100 header names for Matsuba
# Fetched 24100 header names for Lion-Turtle
# Fetched 24100 header names for Mamushi
# Fetched 24100 header names for Matsuri
# Fetched 24100 header names for Kuen
# Fetched 24100 header names for Kurobane
# Fetched 24100 header names for Kyūsuke
# Fetched 24100 header names for Maen_Nara
# Fetched 24100 header names for Makino
# Fetched 24100 header names for Maruten_Akimichi
# Fetched 24100 header names for Kurotsuchi
# Fetched 24100 header names for Malice
# Fetched 24100 header names for Kō_Hyūga
# Fetched 24100 header names for Maki
# Fetched 24100 header names for Kontsuchi
# Fetched 24100 header names for Log
# Fetched 24100 header names for Kushina_Uzumaki
# Fetched 24100 header names for Makaro_Akimichi
# Fetched 24100 header names for Kumade_Toriichi
# Fetched 24100 header names for Konohamaru_Sarutobi
# Fetched 24100 header names for Kyohō_Fuefuki
# Fetched 24100 header names for Leh
# Fetched 24100 header names for Kōji
# Fetched 24100 header names for Kōsuke
# Fetched 24100 header names for Kunihisa
# Fetched 24100 header names for Manda
# Fetched 24100 header names for Kyūroku_Wagarashi
# Fetched 24100 header names for Kurama
# Fetched 24100 header names for Madam_Shijimi
# Fetched 24100 header names for Mai_Kagetsu
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 24200 header names for Kurotsuchi
# Fetched 24200 header names for Kurenai_Yūhi
# Fetched 24200 header names for Konohamaru_Sarutobi
# Fetched 24200 header names for Kurama
# Fetched 24200 header names for Kushina_Uzumaki
# Fetched 24200 header names for Madara_Uchiha
# Fetched 24300 header names for Konohamaru_Sarutobi
# Fetched 24300 header names for Kurama
# Fetched 24300 header names for Madara_Uchiha
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 24400 header names for Konohamaru_Sarutobi
# Fetched 24400 header names for Kurama
# Fetched 24400 header names for Madara_Uchiha
# Fetched 24500 header names for Kurama
# Fetched 24500 header names for Madara_Uchiha
# Total fetched header names: 27346
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 27400 header names for Mecha-Naruto
# Fetched 27400 header names for Mugino
# Fetched 27400 header names for Metal_Lee
# Fetched 27400 header names for Moegi_Kazamatsuri
# Fetched 27400 header names for Mifune
# Fetched 27400 header names for Might_Guy
# Fetched 27400 header names for Mei_Terumī
# Fetched 27400 header names for Minato_Namikaze
# Fetched 27400 header names for Momoshiki_Ōtsutsuki
# Fetched 27400 header names for Mirai_Sarutobi
# Fetched 27400 header names for Mitsuki
# Fetched 27400 header names for Mū
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 27500 header names for Mitsuki
# Fetched 27500 header names for Mei_Terumī
# Fetched 27500 header names for Might_Guy
# Fetched 27500 header names for Minato_Namikaze
# Fetched 27600 header names for Mitsuki
# Fetched 27600 header names for Might_Guy
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 27600 header names for Minato_Namikaze
# Total fetched header names: 30901
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 31000 header names for Obito_Uchiha
# Fetched 31000 header names for Omoi
# Fetched 31000 header names for Nagato
# Fetched 31000 header names for Neji_Hyūga
# Fetched 31000 header names for Orochimaru
# Fetched 31000 header names for Naruto_Uzumaki
# Fetched 31100 header names for Neji_Hyūga
# Fetched 31100 header names for Obito_Uchiha
# Fetched 31100 header names for Nagato
# Fetched 31100 header names for Orochimaru
# Fetched 31100 header names for Naruto_Uzumaki
# Fetched 31200 header names for Obito_Uchiha
# Fetched 31200 header names for Orochimaru
# Fetched 31200 header names for Naruto_Uzumaki
# Fetched 31300 header names for Obito_Uchiha
# Fetched 31300 header names for Orochimaru
# Fetched 31300 header names for Naruto_Uzumaki
# Fetched 31400 header names for Naruto_Uzumaki
# Fetched 31500 header names for Naruto_Uzumaki
# Fetched 31600 header names for Naruto_Uzumaki
# Fetched 31700 header names for Naruto_Uzumaki
# Fetched 31800 header names for Naruto_Uzumaki
# Fetched 31900 header names for Naruto_Uzumaki
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Total fetched header names: 35280
# Fetched 35300 header names for Rō
# Fetched 35300 header names for Rock_Lee
# Fetched 35300 header names for Ryūzetsu
# Fetched 35300 header names for Ryūki
# Fetched 35300 header names for Sadai
# Fetched 35300 header names for Sasori
# Fetched 35300 header names for Ruka
# Fetched 35300 header names for Saya
# Fetched 35300 header names for Shigezane
# Fetched 35300 header names for Shibuki
# Fetched 35300 header names for Sekiei
# Fetched 35300 header names for Seimei
# Fetched 35300 header names for Shiba
# Fetched 35300 header names for Setsuna
# Fetched 35300 header names for Sen
# Fetched 35300 header names for Ryōgi
# Fetched 35300 header names for Rinji
# Fetched 35300 header names for Rin_Nohara
# Fetched 35300 header names for Sekiei_(spectator)
# Fetched 35300 header names for Samui
# Fetched 35300 header names for Rōshi
# Fetched 35300 header names for Sagan
# Fetched 35300 header names for Sana
# Fetched 35300 header names for Saiken
# Fetched 35300 header names for Santa_Yamanaka
# Fetched 35300 header names for Shibi_Aburame
# Fetched 35300 header names for Sakon_and_Ukon
# Fetched 35300 header names for Seiren_Funato
# Fetched 35300 header names for Sai
# Fetched 35300 header names for Shikadai_Nara
# Fetched 35300 header names for Saisu_Kamano
# Fetched 35300 header names for Sarada_Uchiha
# Fetched 35300 header names for Sakumo_Hatake
# Fetched 35300 header names for Shamon
# Fetched 35300 header names for Sakura_Haruno
# Fetched 35300 header names for Sasuke_Uchiha
# Fetched 35400 header names for Sakon_and_Ukon
# Fetched 35400 header names for Shikadai_Nara
# Fetched 35400 header names for Rock_Lee
# Fetched 35400 header names for Sasori
# Fetched 35400 header names for Sasuke_Uchiha
# Fetched 35400 header names for Sai
# Fetched 35400 header names for Sarada_Uchiha
# Fetched 35400 header names for Sakura_Haruno
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 35500 header names for Rock_Lee
# Fetched 35500 header names for Sai
# Fetched 35500 header names for Sarada_Uchiha
# Fetched 35500 header names for Sasuke_Uchiha
# Fetched 35500 header names for Sakura_Haruno
# Fetched 35600 header names for Sai
# Fetched 35600 header names for Sarada_Uchiha
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 35600 header names for Sakura_Haruno
# Fetched 35600 header names for Sasuke_Uchiha
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 35700 header names for Sakura_Haruno
# Fetched 35700 header names for Sasuke_Uchiha
# Fetched 35800 header names for Sakura_Haruno
# Fetched 35800 header names for Sasuke_Uchiha
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 35900 header names for Sasuke_Uchiha
# Total fetched header names: 39794
# Fetched 39800 header names for Shimon_Hijiri
# Fetched 39800 header names for Shin_Uchiha
# Fetched 39800 header names for Shizune
# Fetched 39800 header names for Soul_Tao
# Fetched 39800 header names for Tadaichi
# Fetched 39800 header names for Suika
# Fetched 39800 header names for Suiko
# Fetched 39800 header names for Sukima
# Fetched 39800 header names for Suien
# Fetched 39800 header names for Shiore
# Fetched 39800 header names for Shū_(lord)
# Fetched 39800 header names for Sōsetsu_Kazahana
# Fetched 39800 header names for Shinnō
# Fetched 39800 header names for Suzuran
# Fetched 39800 header names for Shion
# Fetched 39800 header names for Taiko_Uchiha
# Fetched 39800 header names for Suika_Kannonji
# Fetched 39800 header names for Shisō
# Fetched 39800 header names for Sora_(orphan)
# Fetched 39800 header names for Shojoji
# Fetched 39800 header names for Shinbu
# Fetched 39800 header names for Shiin
# Fetched 39800 header names for Shin
# Fetched 39800 header names for Sukune
# Fetched 39800 header names for Son_Gokū
# Fetched 39800 header names for Shiho
# Fetched 39800 header names for Shio
# Fetched 39800 header names for Suzumebachi
# Fetched 39800 header names for Shinobu_Mibu
# Fetched 39800 header names for Shiro
# Fetched 39800 header names for Shura
# Fetched 39800 header names for Shōseki
# Fetched 39800 header names for Sazanami_Senka
# Fetched 39800 header names for Shijima
# Fetched 39800 header names for Shiseru
# Fetched 39800 header names for Suzaku_Nara
# Fetched 39800 header names for Stone_Carver
# Fetched 39800 header names for Suigetsu_Hōzuki
# Fetched 39800 header names for Shizuku_(Taki)
# Fetched 39800 header names for Shira
# Fetched 39800 header names for Shishio
# Fetched 39800 header names for Shinku_Yūhi
# Fetched 39800 header names for Suiu
# Fetched 39800 header names for Sāra's_Daughter
# Fetched 39800 header names for Shinga
# Fetched 39800 header names for Shiranami
# Fetched 39800 header names for Suna_Reincarnated_Shinobi
# Fetched 39800 header names for Suna_Assassin_Captain
# Fetched 39800 header names for Sōma
# Fetched 39800 header names for Shiro_(Land_of_Ancestors)
# Fetched 39800 header names for Shirabe
# Fetched 39800 header names for Shinki
# Fetched 39800 header names for Suzaku_(minister)
# Fetched 39800 header names for Shikuro_Aburame
# Fetched 39800 header names for Shikaku_Nara
# Fetched 39800 header names for Sumaru
# Fetched 39800 header names for Shizuka
# Fetched 39800 header names for Suiren_(Kiri)
# Fetched 39800 header names for Shinko_Inari
# Fetched 39800 header names for Shizuku
# Fetched 39800 header names for Shukaku
# Fetched 39800 header names for Shima
# Fetched 39800 header names for Shino_Aburame
# Fetched 39800 header names for Sora
# Fetched 39800 header names for Shun
# Fetched 39800 header names for Shizuma_Hoshigaki
# Fetched 39800 header names for Shisui_Uchiha
# Fetched 39800 header names for Shitō_Akimichi
# Fetched 39800 header names for Sōzu
# Fetched 39800 header names for Suzume
# Fetched 39800 header names for Shimeji
# Fetched 39800 header names for Suiren
# Fetched 39800 header names for Sumashi
# Fetched 39800 header names for Sumire_Kakei
# Fetched 39800 header names for Sumure
# Fetched 39800 header names for Suguro
# Fetched 39800 header names for Suname
# Fetched 39800 header names for Sky_Ninja_Executive
# Fetched 39800 header names for Sukeza
# Fetched 39800 header names for Shikamaru_Nara
# Fetched 39800 header names for Sāra
# Fetched 39800 header names for Stone_Carver's_Assistant
# Fetched 39800 header names for Shinigami
# Fetched 39800 header names for Shiromari
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 39800 header names for Suzu_Sōgi
# Fetched 39800 header names for Sōsha_Amino
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 39900 header names for Sumire_Kakei
# Fetched 39900 header names for Shizune
# Fetched 39900 header names for Shinki
# Fetched 39900 header names for Shikaku_Nara
# Fetched 39900 header names for Shukaku
# Fetched 39900 header names for Suigetsu_Hōzuki
# Fetched 39900 header names for Shino_Aburame
# Fetched 39900 header names for Shikamaru_Nara
# Fetched 39900 header names for Shisui_Uchiha
# Fetched 40000 header names for Shizune
# Fetched 40000 header names for Shino_Aburame
# Fetched 40000 header names for Shikamaru_Nara
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 40100 header names for Shino_Aburame
# Fetched 40100 header names for Shikamaru_Nara
# Fetched 40200 header names for Shikamaru_Nara
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 40300 header names for Shikamaru_Nara
# Total fetched header names: 43303
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Bow_%26_Arrow: 0, message='', url=URL('https://naruto.fandom.com/wiki/Bow_&_Arrow')
# Fetched 43400 header names for Tayuya
# Fetched 43400 header names for Toneri_Ōtsutsuki
# Fetched 43400 header names for Tenten
# Fetched 43400 header names for Temari
# Fetched 43400 header names for Tobirama_Senju
# Fetched 43500 header names for Tenten
# Fetched 43500 header names for Temari
# Fetched 43500 header names for Tobirama_Senju
# Total fetched header names: 45871
# Fetched 45900 header names for Yanaru_Aze
# Fetched 45900 header names for Tsubaki_Kurogane
# Fetched 45900 header names for Tsuru_Itoi
# Fetched 45900 header names for Urushi_(summon)
# Fetched 45900 header names for Toroi
# Fetched 45900 header names for Tsukino
# Fetched 45900 header names for Yoroi_Akadō
# Fetched 45900 header names for Wasabi_Izuno
# Fetched 45900 header names for Urashiki_Ōtsutsuki
# Fetched 45900 header names for Tsunade
# Fetched 45900 header names for Utakata
# Fetched 45900 header names for Yodo
# Fetched 45900 header names for White_Zetsu
# Fetched 45900 header names for Urakaku
# Fetched 45900 header names for Yahiko
# Fetched 45900 header names for Yamato
# Fetched 45900 header names for Torune_Aburame
# Fetched 45900 header names for Udon_Ise
# Fetched 45900 header names for Yagura_Karatachi
# Fetched 45900 header names for White_Snake_Sage
# Fetched 45900 header names for Victor
# Fetched 45900 header names for Yoshino_Nara
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 45900 header names for Tsume_Inuzuka
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 46000 header names for Utakata
# Fetched 46000 header names for Tsunade
# Fetched 46000 header names for White_Zetsu
# Fetched 46000 header names for Yamato
# Fetched 46100 header names for Tsunade
# Fetched 46100 header names for Yamato
# Fetched 46200 header names for Tsunade
# Total fetched header names: 48837
# TooManyRedirects exception for https://naruto.fandom.com/wiki/Kawaki_%26_Himawari_Academy_Arc: 0, message='', url=URL('https://naruto.fandom.com/wiki/Kawaki_&_Himawari_Academy_Arc')
# Fetched 48900 header names for Yugito_Nii
# Fetched 48900 header names for Yūgao_Uzuki
# Fetched 48900 header names for Zabuza_Momochi
# Fetched 48900 header names for Ōnoki
# Fetched 48900 header names for Yukata
# Fetched 49000 header names for Ōnoki
# Fetched 49100 header names for Ōnoki
# Total fetched header names: 50173

# %% [markdown]
# The corrected link names are stored into a json file:

# %%
with open('../data/characters_links_corrected.json', 'w') as json_file:
    json.dump(characters_links, json_file)

# %% [markdown]
# # Delete?

# %%
import requests
from bs4 import BeautifulSoup

url = "https://naruto.fandom.com/wiki/Enter:_Naruto_Uzumaki!"

# Make an HTTP request to get the HTML content
response = requests.get(url)

if response.status_code == 200:
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the table
    table = soup.find('table', class_='wikitable')

    # Find all rows in the table
    rows = table.find_all('tr')

    # Iterate through rows and extract the text from the 'Role' column
    for row in rows:
        role_column = row.find('td')  # Assuming the 'Role' is in a <td> tag
        if role_column:
            role_text = role_column.get_text(strip=True)
            print(f"Role: {role_text}")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Role: Naruto Uzumaki
# Role: Sasuke Uchiha
# Role: Sakura Haruno
# Role: Third Hokage: Sarutobi
# Role: Iruka
# Role: Shikamaru Nara
# Role: Ino Yamanaka
# Role: Hinata Hyūga
# Role: Mizuki
# Role: Bekkō
# Role: Iwana
# Role: Yajirobee
# Role: Ibara
# Role: Tsubaki
# Role: Tobio's father
# Role: Tobio's mother
# Role: Iruka (boyhood)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://naruto.fandom.com/wiki/Vengeful_Strike!_The_Bracken_Dance!"

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    table = soup.find('table', class_='wikitable')

    rows = table.find_all('tr')

    header_row = rows[0]
    headers = [header.get_text(strip=True) for header in header_row.find_all('th')]

    # Iterate through rows and extract the role and associated header name
    for row in rows[1:]:  # Start from the second row to skip the header row
        role_column = row.find('td')  # Assuming the 'Role' is in a <td> tag
        if role_column:
            role_link = role_column.find('a')  # Assuming the role is a hyperlink
            if role_link:
                role_text = role_link.get_text(strip=True)
                title_attribute = role_link.get('title', '')
                print(f"Role: {role_text}, Title: {title_attribute}")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Role: Naruto Uzumaki, Title: Naruto Uzumaki
# Role: Rock Lee, Title: Rock Lee
# Role: Gaara, Title: Gaara
# Role: Kimimaro, Title: Kimimaro
# Role: Orochimaru, Title: Orochimaru
# Role: Kabuto Yakushi, Title: Kabuto Yakushi
# Role: Kazekage, Title: Rasa
# Role: Sakon, Title: Sakon
# Role: Kidōmaru, Title: Kidōmaru
# Role: Tayuya, Title: Tayuya
# Role: Jirōbō, Title: Jirōbō
